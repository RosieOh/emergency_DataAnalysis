# %%
import pandas as pd

# %%
emergency_operate= pd.read_csv("/Users/otaehun/Desktop/의료인력/소방청_119 구급상황관리센터 운영 현황_20201231.csv",
                        encoding='utf-8')
emergency_operate
# Out:
#     본부별  의료상담 병원  의료상담 약국   질병상담  응급처치지도   의료지도  이송병원안내  구급차출동    기타
# 0   서 울   142407     6586  74125   68994  22485       8      0   295
# 1   부 산    72282     8460  18370   22544   6693    2679      0  4365
# 2   대 구    39207     4177   6466   12852  12101       7      0     2
# 3   인 천    14707     2973   5659   22335   6669      74      0   255
# 4   광 주     9546     1484   3155   15525   5465      15      1    28
# 5   대 전    30919     1313   3650   11490   8829      34     11   180
# 6   울 산     7580      793   1890   15313   4205      33     19    31
# 7   세 종     6278      197    447     191   3068       4      0  3192
# 8   경 기    61430     5041  48969   64884  24785      23    250  1061
# 9   강 원     9092     7296   4974   11713   5797       2      7   717
# 10  충 북    15652     2116   2781   16500   1648    1140    124   720
# 11  충 남    17624     1472   3952    8232   4185      31     17   132
# 12  전 북    17150     4390   3568   20343   4734      34    194   955
# ...

# %%
emergency_operate1 = emergency_operate[['본부별', '질병상담', '의료지도', '이송병원안내']]

emergency_operate1
# Out:
#     본부별   질병상담   의료지도  이송병원안내
# 0   서 울  74125  22485       8
# 1   부 산  18370   6693    2679
# 2   대 구   6466  12101       7
# 3   인 천   5659   6669      74
# 4   광 주   3155   5465      15
# 5   대 전   3650   8829      34
# 6   울 산   1890   4205      33
# 7   세 종    447   3068       4
# 8   경 기  48969  24785      23
# 9   강 원   4974   5797       2
# 10  충 북   2781   1648    1140
# 11  충 남   3952   4185      31
# 12  전 북   3568   4734      34
# 13  전 남   1707   3211      12
# 14  경 북   7546  11605      20
# 15  경 남   4697   5626     176
# 16  창 원    582    169       2
# 17  제 주   3001   4625     267

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.boxplot(x="본부별", 

            y="의료지도", 

            data = emergency_operate1)

plt.show()

# %%
import matplotlib.pyplot as plt
emergency_operate1.hist(bins=20)
plt.show()

# %%
import matplotlib.pyplot as plt
emergency_operate1.boxplot(column='질병상담') 
plt.ylim(10, 10000)
# Out:
# (10.0, 10000.0)

# %%
emergency_operate1.boxplot(column='의료지도', by='본부별' )
plt.ylim(1000, 10000)
# Out:
# (1000.0, 10000.0)

# %%
emergency_call= pd.read_csv("/Users/otaehun/Desktop/의료인력/소방청_119신고 전화 유형_20201231.csv",
                        encoding='utf-8')
emergency_call
# Out:
#      연도별  유형     화 재     구 조      구 급  대민출동 및 기타  유관기관 이첩  안내 및 민원   장난전화  \
# 0   2011  유선   61504  137825   747385     317208    48941   733607   8301
# 1   2011  무선  160109  221549  1292905     281186    77290  1752950  11996
# 2   2012  유선   61905  162541   775063     218646    37245  1117417   6863
# 3   2012  무선  160905  300521  1358292     227808    83532  1906533  11054
# 4   2013  유선   51847  132055   734678     271719    39297  1305252   3800
# 5   2013  무선  155010  301058  1449000     277562    88071  2205184   3398
# 6   2014  유선   54003  131932   664883     346849    28086  1043680   1634
# 7   2014  무선  187580  341507  1706341     287005    83016  2189825   1598
# 8   2015  유선   51416  115197   636413     336634    15032   835236    845
# 9   2015  무선  191944  361668  1825727     247870    61715  2278975   1422
# 10  2016  유선   40323  103896   466356     310251    13092   556351    622
# 11  2016  무선  194475  490960  2103004     270275   113991  2659969   1472
# ...

# %%
emergency_call1 = emergency_call[['연도별', '유형', '구 급']]

emergency_call1
# Out:
#      연도별  유형      구 급
# 0   2011  유선   747385
# 1   2011  무선  1292905
# 2   2012  유선   775063
# 3   2012  무선  1358292
# 4   2013  유선   734678
# 5   2013  무선  1449000
# 6   2014  유선   664883
# 7   2014  무선  1706341
# 8   2015  유선   636413
# 9   2015  무선  1825727
# 10  2016  유선   466356
# 11  2016  무선  2103004
# 12  2017  유선   432855
# 13  2017  무선  2234678
# 14  2018  유선   370942
# 15  2018  무선  2354344
# 16  2019  유선   312193
# 17  2019  무선  2372582
# 18  2020  유선   258428
# 19  2020  무선  2260522

# %%
del emergency_call
emergency_call.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f08f739350fa> in <module>
#       1 del emergency_call
# ----> 2 emergency_call.head()
#
# NameError: name 'emergency_call' is not defined

# %%
import numpy as np

import pandas as pd



import matplotlib.pyplot as plt

import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 6]

# %matplotlib inline

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
# %matplotlib inline
[f.name for f in font_manager.fontManager.ttflist if 'Neo' in f.name]
# Out:
# ['Apple SD Gothic Neo']

# %%
# 운영체제별 글꼴 세팅

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    font_name = 'Apple SD Gothic Neo'
    rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# %%
import seaborn as sns
sns.boxplot(x="연도별", 

            y="구 급", 

            data=emergency_call1)

plt.show()

# %%
ax = sns.regplot(x='연도별',y='구 급',data=emergency_call1 ) 
# fit_reg=False 선형선 출력하지 않는 옵션
# ax = sns.regplot(x='total_bill',y='tip',
#                 data=tips, fit_reg=False ) 
ax.set_xlabel('연도별')  # x축 이름 설정
ax.set_ylabel('응 급 환 자') # y축 이름 설정
ax.set_title('Total 연도별 and 응급환자') # 그래프 제목 설정
# Out:
# Text(0.5, 1.0, 'Total 연도별 and 응급환자')

# %%
emergency_activity= pd.read_csv("/Users/otaehun/Desktop/의료인력/소방청_구조활동현황_12_31_2019.csv",
                        encoding='utf-8')
emergency_activity
# Out:
#               번호      신고년월일   신고시각      출동년월일   출동시각 발생장소_시    발생장소_구 발생장소_동  \
# 0              1   2015.1.1   0:11   2015.1.1   0:16    경기도   안산시 상록구     사동
# 1              2   2015.1.1   0:13   2015.1.1   0:14    경기도  고양시 일산동구    마두동
# 2              3   2015.1.1   0:18   2015.1.1   0:20    경기도   성남시 분당구    서현동
# 3              4   2015.1.1   0:22   2015.1.1   0:24    경기도   성남시 분당구    구미동
# 4              5   2015.1.1   0:22   2015.1.1   0:24    경기도   성남시 분당구    구미동
# ...          ...        ...    ...        ...    ...    ...       ...    ...
# 1048570  1048571  2015.10.4  23:53  2015.10.4  23:55  서울특별시       중랑구     묵동
# 1048571  1048572  2015.10.5  11:04  2015.10.5  11:05  서울특별시       중랑구    신내동
# 1048572  1048573  2015.10.5  16:56  2015.10.5  16:59  서울특별시       중랑구    신내동
# 1048573  1048574  2015.10.5  17:06  2015.10.5  17:07  서울특별시       중랑구    신내동
# 1048574  1048575  2015.10.5  17:06  2015.10.5  17:08  서울특별시       중랑구    신내동
#
#            사고원인 사고원인코드명_사고종별
# ...
